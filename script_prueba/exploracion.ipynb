# %%
import pandas as pd
import missingno as msno
import numpy as np

# %%
videogames = pd.read_csv(r"C:\Users\nmvan\Documents\Complexivo\Grupo9_CasoEstudioMovilidadUrbana\data\games.csv")
casoestudio = pd.read_csv(r"C:\Users\nmvan\Documents\Complexivo\Grupo9_CasoEstudioMovilidadUrbana\data\yellow_tripdata_2015-01.csv", sep=',')

# %%
videogames.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
type(videogames)
# Out:
# pandas.core.frame.DataFrame

# %%
videogames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
videogames.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %%
videogames.rename(
    columns={
        'Name': 'Videogame_names',
        'Rating': 'Rating_ESRB'
    }, inplace=True
)

# %%
videogames.head()
# Out:
#             Videogame_names Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating_ESRB
# 0     28.96      3.77         8.45          76.0          8           E
# 1      3.58      6.81         0.77           NaN        NaN         NaN
# 2     12.76      3.79         3.29          82.0        8.3           E
# 3     10.93      3.28         2.95          80.0          8           E
# 4      8.89     10.22         1.00           NaN        NaN         NaN

# %% [markdown]
# Codigo para visulizar valores ausnees y valore unicos

# %%
videogames.nunique()
# Out:
# Videogame_names    11559
# Platform              31
# Year_of_Release       37
# Genre                 12
# NA_sales             402
# EU_sales             307
# JP_sales             244
# Other_sales          155
# Critic_Score          82
# User_Score            96
# Rating_ESRB            8
# dtype: int64

# %%
videogames.isnull().sum()
# Out:
# Videogame_names       2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating_ESRB        6766
# dtype: int64

# %%
type(videogames["Platform"])
# Out:
# pandas.core.series.Series

# %%
videogames.isnull().sum().info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 11 entries, Videogame_names to Rating_ESRB
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 11 non-null     int64
# dtypes: int64(1)
# memory usage: 476.0+ bytes

# %%
videogames.isnull().sum()["Rating_ESRB"]
# Out:
# np.int64(6766)

# %%
valores_unicos= videogames.nunique()

# %%
pd.DataFrame({
    "Valores únicos" : valores_unicos,
    "nulos" : videogames.isnull().sum()
}    
)
# Out:
#                  Valores únicos  nulos
# Videogame_names           11559      2
# Platform                     31      0
# Year_of_Release              37    269
# Genre                        12      2
# NA_sales                    402      0
# EU_sales                    307      0
# JP_sales                    244      0
# Other_sales                 155      0
# Critic_Score                 82   8578
# User_Score                   96   6701
# Rating_ESRB                   8   6766

# %%
videogames.isnull().sum()
# Out:
# Videogame_names       2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating_ESRB        6766
# dtype: int64

# %% [markdown]
# Promedio de datos de datos ausentes que hay en cada columna y nos a en porcentaje

# %%
round(videogames.isnull().mean()*100, 2)
# Out:
# Videogame_names     0.01
# Platform            0.00
# Year_of_Release     1.61
# Genre               0.01
# NA_sales            0.00
# EU_sales            0.00
# JP_sales            0.00
# Other_sales         0.00
# Critic_Score       51.32
# User_Score         40.09
# Rating_ESRB        40.48
# dtype: float64

# %% [markdown]
# con la libre misin auda a crear visualiacion de datos  en barras y matrix y para sber en que posicion tengo valores ausente

# %%
msno.matrix(videogames)
# Out:
# <Axes: >

# %%
msno.bar(videogames)
# Out:
# <Axes: >

# %% [markdown]
# un daigra de calor nos sirve para ver los valores ausnte y le die ene l cluman esta

# %%
msno.heatmap(videogames)
# Out:
# <Axes: >

# %%
msno.bar(casoestudio)
# Out:
# <Axes: >

# %% [markdown]
# Cnteo total de datp

# %%
casoestudio["pickup_latitude"].value_counts()
# Out:
# pickup_latitude
# 0.000000     243478
# 40.774109      2693
# 40.774078      2681
# 40.774101      2655
# 40.774071      2654
#               ...
# 40.634304         1
# 40.578716         1
# 40.866909         1
# 40.864765         1
# 40.652855         1
# Name: count, Length: 62748, dtype: int64

# %%
casoestudio["pickup_latitude"].value_counts(normalize=True)*100
# Out:
# pickup_latitude
# 0.000000     1.909783
# 40.774109    0.021123
# 40.774078    0.021029
# 40.774101    0.020825
# 40.774071    0.020817
#                ...
# 40.634304    0.000008
# 40.578716    0.000008
# 40.866909    0.000008
# 40.864765    0.000008
# 40.652855    0.000008
# Name: proportion, Length: 62748, dtype: float64

# %% [markdown]
# automatizacion del codigo vale counts

# %%
casoestudio.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RateCodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
for columna in casoestudio.columns:
    print(f"Columna: {columna}")
    print(casoestudio[columna].value_counts(normalize=True)*100)
    print("--------------------------------------------------")
# Out:
# Columna: VendorID
# VendorID
# 2    52.143731
# 1    47.856269
# Name: proportion, dtype: float64
# --------------------------------------------------
# Columna: tpep_pickup_datetime
# tpep_pickup_datetime
# 2015-01-05 09:39:49    0.000737
# 2015-01-12 19:02:27    0.000322
# 2015-01-12 18:55:17    0.000306
# 2015-01-14 16:13:52    0.000251
# 2015-01-14 13:20:13    0.000227
#                          ...
# 2015-01-30 13:46:09    0.000008
# 2015-01-10 06:07:00    0.000008
# 2015-01-26 06:05:19    0.000008
# 2015-01-15 17:05:40    0.000008
# 2015-01-10 06:06:43    0.000008
# Name: proportion, Length: 2438284, dtype: float64
# --------------------------------------------------
# Columna: tpep_dropoff_datetime
# tpep_dropoff_datetime
# 2015-01-02 00:00:00    0.001114
# 2015-01-04 00:00:00    0.001043
# 2015-02-01 00:00:00    0.001035
# 2015-01-03 00:00:00    0.001012
# 2015-01-11 00:00:00    0.000933
#                          ...
# 2015-01-10 06:11:25    0.000008
# ...

# %%
(videogames["Genre"].value_counts(normalize=True)*100).reset_index().sort_values(by="Genre", ascending=True)
# Out:
#            Genre  proportion
# 0         Action   20.157961
# 5      Adventure    7.796326
# 9       Fighting    5.079878
# 2           Misc   10.470891
# 7       Platform    5.313229
# 11        Puzzle    3.470352
# 6         Racing    7.473224
# 3   Role-Playing    8.963083
# 4        Shooter    7.915994
# 8     Simulation    5.223479
# 1         Sports   14.048944
# 10      Strategy    4.086639

# %% [markdown]
# ## resumen estadistico . decribe()

# %%
videogames.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
casoestudio.describe()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  1.274899e+07     1.274899e+07   1.274899e+07      1.274899e+07
# mean   1.521437e+00     1.681491e+00   1.345913e+01     -7.256184e+01
# std    4.995402e-01     1.337924e+00   9.844094e+03      1.012510e+01
# min    1.000000e+00     0.000000e+00   0.000000e+00     -1.219258e+02
# 25%    1.000000e+00     1.000000e+00   1.000000e+00     -7.399168e+01
# 50%    2.000000e+00     1.000000e+00   1.680000e+00     -7.398160e+01
# 75%    2.000000e+00     2.000000e+00   3.000000e+00     -7.396662e+01
# max    2.000000e+00     9.000000e+00   1.542000e+07      7.866265e+01
#
#        pickup_latitude    RateCodeID  dropoff_longitude  dropoff_latitude  \
# count     1.274899e+07  1.274899e+07       1.274899e+07      1.274899e+07
# mean      3.997282e+01  1.036901e+00      -7.260904e+01      3.999961e+01
# std       5.578691e+00  6.732240e-01       9.966037e+00      5.487742e+00
# ...

# %%
videogames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
casoestudio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12748986 entries, 0 to 12748985
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   pickup_longitude       float64
#  6   pickup_latitude        float64
#  7   RateCodeID             int64
#  8   store_and_fwd_flag     object
#  9   dropoff_longitude      float64
#  10  dropoff_latitude       float64
#  11  payment_type           int64
#  12  fare_amount            float64
#  13  extra                  float64
#  14  mta_tax                float64
#  15  tip_amount             float64
#  16  tolls_amount           float64
#  17  improvement_surcharge  float64
#  18  total_amount           float64
# dtypes: float64(12), int64(4), object(3)
# memory usage: 1.8+ GB

# %%
categoriacal_data = videogames.select_dtypes(include=["object"])
categoriacal_data.describe()
# Out:
#                                Name Platform   Genre User_Score Rating
# count                         16713    16715   16713      10014   9949
# unique                        11559       31      12         96      8
# top     Need for Speed: Most Wanted      PS2  Action        tbd      E
# freq                             12     2161    3369       2424   3990

# %%
categoriacal_data_caso = casoestudio.select_dtypes(include=["object"])
categoriacal_data_caso.describe()
# Out:
#        tpep_pickup_datetime tpep_dropoff_datetime store_and_fwd_flag
# count              12748986              12748986           12748986
# unique              2438284               2442163                  2
# top     2015-01-05 09:39:49   2015-01-02 00:00:00                  N
# freq                     94                   142           12633953

# %%
numerical_data_caso = casoestudio.select_dtypes(include=["float64"])
numerical_data_caso.describe()
# Out:
#        trip_distance  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count   1.274899e+07      1.274899e+07     1.274899e+07       1.274899e+07
# mean    1.345913e+01     -7.256184e+01     3.997282e+01      -7.260904e+01
# std     9.844094e+03      1.012510e+01     5.578691e+00       9.966037e+00
# min     0.000000e+00     -1.219258e+02     0.000000e+00      -7.401667e+02
# 25%     1.000000e+00     -7.399168e+01     4.073554e+01      -7.399120e+01
# 50%     1.680000e+00     -7.398160e+01     4.075314e+01      -7.397976e+01
# 75%     3.000000e+00     -7.396662e+01     4.076757e+01      -7.396246e+01
# max     1.542000e+07      7.866265e+01     4.047000e+02       8.527402e+01
#
#        dropoff_latitude   fare_amount         extra       mta_tax  \
# count      1.274899e+07  1.274899e+07  1.274899e+07  1.274899e+07
# mean       3.999961e+01  1.190566e+01  3.082790e-01  4.977986e-01
# std        5.487742e+00  1.030254e+01  5.916643e-01  3.534229e-02
# ...

# %% [markdown]
# ## conversion de string a date

# %%
casoestudio["tpep_pickup_datetime"] = pd.to_datetime(casoestudio["tpep_pickup_datetime"],format="%Y-%m-%d %H:%M:%S")
casoestudio["tpep_dropoff_datetime"] = pd.to_datetime(casoestudio["tpep_dropoff_datetime"],format="%Y-%m-%d %H:%M:%S")

print(casoestudio["tpep_pickup_datetime"])
print(casoestudio["tpep_dropoff_datetime"])
# Out:
# 0          2015-01-15 19:05:39
# 1          2015-01-10 20:33:38
# 2          2015-01-10 20:33:38
# 3          2015-01-10 20:33:39
# 4          2015-01-10 20:33:39
#                    ...
# 12748981   2015-01-10 19:01:44
# 12748982   2015-01-10 19:01:44
# 12748983   2015-01-10 19:01:44
# 12748984   2015-01-10 19:01:44
# 12748985   2015-01-10 19:01:45
# Name: tpep_pickup_datetime, Length: 12748986, dtype: datetime64[ns]
# 0          2015-01-15 19:23:42
# 1          2015-01-10 20:53:28
# 2          2015-01-10 20:43:41
# 3          2015-01-10 20:35:31
# 4          2015-01-10 20:52:58
#                    ...
# 12748981   2015-01-10 19:05:40
# 12748982   2015-01-10 19:07:26
# 12748983   2015-01-10 19:15:01
# 12748984   2015-01-10 19:17:03
# 12748985   2015-01-10 19:07:33
# Name: tpep_dropoff_datetime, Length: 12748986, dtype: datetime64[ns]

# %% [markdown]
# # Limpieza de datos

# %%
casoestudio.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RateCodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount'],
#       dtype='object')

# %%
casoestudio = casoestudio[(casoestudio["pickup_longitude"]!= 0) & (casoestudio["pickup_latitude"] != 0)]
print(casoestudio)
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1                1  2015-01-10 20:33:38   2015-01-10 20:53:28
# 2                1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 3                1  2015-01-10 20:33:39   2015-01-10 20:35:31
# 4                1  2015-01-10 20:33:39   2015-01-10 20:52:58
# ...            ...                  ...                   ...
# 12748981         1  2015-01-10 19:01:44   2015-01-10 19:05:40
# 12748982         1  2015-01-10 19:01:44   2015-01-10 19:07:26
# 12748983         1  2015-01-10 19:01:44   2015-01-10 19:15:01
# 12748984         1  2015-01-10 19:01:44   2015-01-10 19:17:03
# 12748985         1  2015-01-10 19:01:45   2015-01-10 19:07:33
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       1           1.59        -73.993896        40.750111
# ...

# %%
casoestudio[casoestudio.pickup_longitude.isna()]
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, pickup_longitude, pickup_latitude, RateCodeID, store_and_fwd_flag, dropoff_longitude, dropoff_latitude, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount]
# Index: []

# %%
casoestudio
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1                1  2015-01-10 20:33:38   2015-01-10 20:53:28
# 2                1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 3                1  2015-01-10 20:33:39   2015-01-10 20:35:31
# 4                1  2015-01-10 20:33:39   2015-01-10 20:52:58
# ...            ...                  ...                   ...
# 12748981         1  2015-01-10 19:01:44   2015-01-10 19:05:40
# 12748982         1  2015-01-10 19:01:44   2015-01-10 19:07:26
# 12748983         1  2015-01-10 19:01:44   2015-01-10 19:15:01
# 12748984         1  2015-01-10 19:01:44   2015-01-10 19:17:03
# 12748985         1  2015-01-10 19:01:45   2015-01-10 19:07:33
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       1           1.59        -73.993896        40.750111
# ...

# %%
casoestudio.drop(columns=["fare_amount"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 casoestudio.drop(columns=["fare_amount"], inplace=True)
#
# File c:\Users\nmvan\Documents\Complexivo\Grupo9_CasoEstudioMovilidadUrbana\venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
# ...

# %%
casoestudio
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1                1  2015-01-10 20:33:38   2015-01-10 20:53:28
# 2                1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 3                1  2015-01-10 20:33:39   2015-01-10 20:35:31
# 4                1  2015-01-10 20:33:39   2015-01-10 20:52:58
# ...            ...                  ...                   ...
# 12748981         1  2015-01-10 19:01:44   2015-01-10 19:05:40
# 12748982         1  2015-01-10 19:01:44   2015-01-10 19:07:26
# 12748983         1  2015-01-10 19:01:44   2015-01-10 19:15:01
# 12748984         1  2015-01-10 19:01:44   2015-01-10 19:17:03
# 12748985         1  2015-01-10 19:01:45   2015-01-10 19:07:33
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       1           1.59        -73.993896        40.750111
# ...

# %%
casoestudio.drop(columns=["payment_type"], inplace=True)

# %%
casoestudio
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1                1  2015-01-10 20:33:38   2015-01-10 20:53:28
# 2                1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 3                1  2015-01-10 20:33:39   2015-01-10 20:35:31
# 4                1  2015-01-10 20:33:39   2015-01-10 20:52:58
# ...            ...                  ...                   ...
# 12748981         1  2015-01-10 19:01:44   2015-01-10 19:05:40
# 12748982         1  2015-01-10 19:01:44   2015-01-10 19:07:26
# 12748983         1  2015-01-10 19:01:44   2015-01-10 19:15:01
# 12748984         1  2015-01-10 19:01:44   2015-01-10 19:17:03
# 12748985         1  2015-01-10 19:01:45   2015-01-10 19:07:33
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                       1           1.59        -73.993896        40.750111
# ...
